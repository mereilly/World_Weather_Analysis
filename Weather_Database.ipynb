# %% [markdown]
# # Deliverable 1 - Collecting Datapoints From an API

# %%
#Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time

from datetime import datetime

from citipy import citipy
from config import WEATHER_API_KEY

# %%
# Making url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + WEATHER_API_KEY

# %%
#Creating set of random coordinates
num_locs=2000

lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Adding the coordinates to a list
coordinates = list(lat_lngs)

# %%
# Create lists to store cities and countries.
cities = []

# Loop over the coordinates.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Only append if it is a new city.
    if city not in cities:
        cities.append(city)
    
# Sanity checks:
print (f"Initial count of cities: {len(cities)}")
# Out:
# Initial count of cities: 728

# %%
# Base URL for the OpenWeather API call.
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + WEATHER_API_KEY

print(f"Beginning Data Retrieval")
print("---------------------------\n")

# Create an empty list to hold the weather data.
city_data = []

#Start and create counter lists
record_count = 1
set_count = 1

# Initialize variables to keep track of rate limiting.
start_time = int(time.time())
current_time = start_time

# Loop over all cities.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    print (f"Processing record {record_count} of set {set_count} | {city}")
    record_count += 1
        
    if i > 0:
        # Get current time.
        current_time = int(time.time())
        
#         # If needed introduce a sleep process so not to get blocked by API, if we surpass a certain amount of calls and 1 min hasn't passed, the code will add a sleep break
#     elif current_time - start_time < 60:
#         sleep_time = 60 - (current_time - start_time)
#         print (f"Introducting a sleep of {sleep_time} seconds!")
#         time.sleep(sleep_time) 
        
            # Get the new start time.
    start_time = int(time.time())
        
    
    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")
    
    #https://docs.python.org/3.6/tutorial/errors.html
    try:
    
        city_weather = requests.get(city_url).json()
        lat = city_weather["coord"]["lat"]
        lng = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        current = city_weather["weather"][0]["description"]

        #Convert date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
        #Append city info to city_data list.
        city_data.append({"City": city,
                          "Lat": lat,
                          "Lng": lng,
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": clouds,
                          "Wind Speed": wind,
                          "Country": country,
                          "Current Description": current})
        
        city_weather = requests.get(city_url).json()
    
        
        # Parse out the needed data.
        lat = city_weather["coord"]["lat"]
        lng = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        desc = city_weather['weather'][0]['description']

        # Append the city information into city_data list.
        city_data.append({'City': city.title(),
                          'Lat': lat,
                          'Lng': lng,
                          'Max Temp': max_temp,
                          'Humidity': humidity,
                          'Cloudiness': clouds,
                          'Wind Speed': wind,
                          'Country': country,
                          'Current Description': desc})

       
    # Skip errors
    except:
        print("City not found. Skipping...")
        pass
    
#Indicate Data Loading complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
#
# Processing record 1 of set 1 | tuatapere
# Processing record 2 of set 1 | butaritari
# Processing record 3 of set 1 | ugento
# Processing record 4 of set 1 | bredasdorp
# Processing record 5 of set 1 | podporozhye
# Processing record 6 of set 1 | ust-nera
# Processing record 7 of set 1 | severo-kurilsk
# Processing record 8 of set 1 | barrow
# Processing record 9 of set 1 | hilo
# Processing record 10 of set 1 | brigantine
# Processing record 11 of set 1 | melfi
# Processing record 12 of set 1 | rikitea
# Processing record 13 of set 1 | cherskiy
# Processing record 14 of set 1 | lorengau
# Processing record 15 of set 1 | georgetown
# Processing record 16 of set 1 | wittenheim
# Processing record 17 of set 1 | mataura
# Processing record 18 of set 1 | kavieng
# Processing record 19 of set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing record 20 of set 1 | albany
# Processing record 21 of set 1 | rio gallegos
# Processing record 22 of set 1 | klaksvik
# Processing record 23 of set 1 | punta arenas
# Processing record 24 of set 1 | attawapiskat
# City not found. Skipping...
# Processing record 25 of set 1 | port macquarie
# Processing record 26 of set 1 | vila franca do campo
# Processing record 27 of set 1 | rungata
# City not found. Skipping...
# Processing record 28 of set 1 | banjar
# Processing record 29 of set 1 | mikkeli
# Processing record 30 of set 1 | gawler
# Processing record 31 of set 1 | nelson bay
# Processing record 32 of set 1 | woodward
# Processing record 33 of set 1 | tena
# Processing record 34 of set 1 | ancud
# Processing record 35 of set 1 | alihe
# Processing record 36 of set 1 | busselton
# Processing record 37 of set 1 | puerto ayora
# Processing record 38 of set 1 | bressuire
# Processing record 39 of set 1 | jamestown
# Processing record 40 of set 1 | luderitz
# Processing record 41 of set 1 | belushya guba
# City not found. Skipping...
# Processing record 42 of set 1 | bambous virieux
# Processing record 43 of set 1 | cayenne
# Processing record 44 of set 1 | atuona
# Processing record 45 of set 1 | clyde river
# Processing record 46 of set 1 | flin flon
# Processing record 47 of set 1 | todos santos
# Processing record 48 of set 1 | cape town
# Processing record 49 of set 1 | gomel
# Processing record 50 of set 1 | east london
# Processing record 1 of set 2 | leningradskiy
# Processing record 2 of set 2 | dordrecht
# Processing record 3 of set 2 | bilibino
# Processing record 4 of set 2 | sao filipe
# Processing record 5 of set 2 | faanui
# Processing record 6 of set 2 | marienburg
# Processing record 7 of set 2 | kuli
# Processing record 8 of set 2 | muyezerskiy
# Processing record 9 of set 2 | port elizabeth
# Processing record 10 of set 2 | tuktoyaktuk
# Processing record 11 of set 2 | new norfolk
# Processing record 12 of set 2 | port alfred
# Processing record 13 of set 2 | herat
# Processing record 14 of set 2 | kutum
# Processing record 15 of set 2 | arraial do cabo
# Processing record 16 of set 2 | gizeh
# Processing record 17 of set 2 | bluff
# Processing record 18 of set 2 | vostok
# Processing record 19 of set 2 | bethel
# Processing record 20 of set 2 | ushuaia
# Processing record 21 of set 2 | emerald
# Processing record 22 of set 2 | buchanan
# Processing record 23 of set 2 | saint anthony
# Processing record 24 of set 2 | khatanga
# Processing record 25 of set 2 | erzin
# Processing record 26 of set 2 | pangody
# Processing record 27 of set 2 | katsuura
# Processing record 28 of set 2 | lagoa
# Processing record 29 of set 2 | taolanaro
# City not found. Skipping...
# Processing record 30 of set 2 | mentok
# City not found. Skipping...
# Processing record 31 of set 2 | qaanaaq
# Processing record 32 of set 2 | norman wells
# Processing record 33 of set 2 | sioux lookout
# Processing record 34 of set 2 | hobart
# Processing record 35 of set 2 | dali
# Processing record 36 of set 2 | opuwo
# Processing record 37 of set 2 | nanortalik
# Processing record 38 of set 2 | yatou
# Processing record 39 of set 2 | broome
# Processing record 40 of set 2 | los llanos de aridane
# Processing record 41 of set 2 | kapaa
# Processing record 42 of set 2 | ilulissat
# Processing record 43 of set 2 | harper
# Processing record 44 of set 2 | sobolevo
# Processing record 45 of set 2 | aklavik
# Processing record 46 of set 2 | coihueco
# Processing record 47 of set 2 | port hedland
# Processing record 48 of set 2 | pestovo
# Processing record 49 of set 2 | yellowknife
# Processing record 50 of set 2 | xichang
# Processing record 1 of set 3 | tsihombe
# City not found. Skipping...
# Processing record 2 of set 3 | port lincoln
# Processing record 3 of set 3 | mys shmidta
# City not found. Skipping...
# Processing record 4 of set 3 | lucap
# Processing record 5 of set 3 | menongue
# Processing record 6 of set 3 | suao
# City not found. Skipping...
# Processing record 7 of set 3 | pasni
# Processing record 8 of set 3 | luganville
# Processing record 9 of set 3 | quang ngai
# Processing record 10 of set 3 | verkhnevilyuysk
# Processing record 11 of set 3 | sao felix do xingu
# Processing record 12 of set 3 | yulara
# Processing record 13 of set 3 | flinders
# Processing record 14 of set 3 | tsimlyansk
# Processing record 15 of set 3 | barentsburg
# City not found. Skipping...
# Processing record 16 of set 3 | iranshahr
# Processing record 17 of set 3 | sabang
# Processing record 18 of set 3 | vaini
# Processing record 19 of set 3 | saskylakh
# Processing record 20 of set 3 | nizhneyansk
# City not found. Skipping...
# Processing record 21 of set 3 | saint-philippe
# Processing record 22 of set 3 | brazzaville
# Processing record 23 of set 3 | riviere-au-renard
# Processing record 24 of set 3 | kruisfontein
# Processing record 25 of set 3 | souillac
# Processing record 26 of set 3 | ksenyevka
# City not found. Skipping...
# Processing record 27 of set 3 | nikolskoye
# Processing record 28 of set 3 | treinta y tres
# Processing record 29 of set 3 | bengkulu
# Processing record 30 of set 3 | dudinka
# Processing record 31 of set 3 | bien hoa
# Processing record 32 of set 3 | olga
# Processing record 33 of set 3 | meulaboh
# Processing record 34 of set 3 | henties bay
# Processing record 35 of set 3 | herisau
# Processing record 36 of set 3 | kaitangata
# Processing record 37 of set 3 | salalah
# Processing record 38 of set 3 | longyearbyen
# Processing record 39 of set 3 | castro
# Processing record 40 of set 3 | kununurra
# Processing record 41 of set 3 | esperance
# Processing record 42 of set 3 | hualmay
# Processing record 43 of set 3 | pontiac
# Processing record 44 of set 3 | ust-ishim
# Processing record 45 of set 3 | thompson
# Processing record 46 of set 3 | jaciara
# Processing record 47 of set 3 | vardo
# Processing record 48 of set 3 | naberera
# Processing record 49 of set 3 | roald
# Processing record 50 of set 3 | teshie
# Processing record 1 of set 4 | buin
# Processing record 2 of set 4 | ponta do sol
# Processing record 3 of set 4 | mongagua
# Processing record 4 of set 4 | paka
# Processing record 5 of set 4 | olinda
# Processing record 6 of set 4 | pevek
# Processing record 7 of set 4 | saint-georges
# Processing record 8 of set 4 | riyadh
# Processing record 9 of set 4 | kodiak
# Processing record 10 of set 4 | dryden
# Processing record 11 of set 4 | severnoye
# Processing record 12 of set 4 | kawalu
# Processing record 13 of set 4 | rocha
# Processing record 14 of set 4 | west plains
# Processing record 15 of set 4 | ust-kulom
# Processing record 16 of set 4 | yibin
# Processing record 17 of set 4 | muroto
# Processing record 18 of set 4 | jinchang
# Processing record 19 of set 4 | codrington
# Processing record 20 of set 4 | abilene
# Processing record 21 of set 4 | ifanadiana
# Processing record 22 of set 4 | hermanus
# Processing record 23 of set 4 | madimba
# Processing record 24 of set 4 | port hardy
# Processing record 25 of set 4 | cherrapunji
# Processing record 26 of set 4 | cidreira
# Processing record 27 of set 4 | yanam
# Processing record 28 of set 4 | tiksi
# Processing record 29 of set 4 | pundaguitan
# Processing record 30 of set 4 | dover
# Processing record 31 of set 4 | avarua
# Processing record 32 of set 4 | sentyabrskiy
# City not found. Skipping...
# Processing record 33 of set 4 | lima
# Processing record 34 of set 4 | port-gentil
# Processing record 35 of set 4 | cruz alta
# Processing record 36 of set 4 | sembe
# Processing record 37 of set 4 | sacramento
# Processing record 38 of set 4 | mehamn
# Processing record 39 of set 4 | foki
# Processing record 40 of set 4 | brae
# Processing record 41 of set 4 | ambon
# Processing record 42 of set 4 | rongcheng
# Processing record 43 of set 4 | kamaishi
# Processing record 44 of set 4 | vestmannaeyjar
# Processing record 45 of set 4 | taunggyi
# Processing record 46 of set 4 | roanoke rapids
# Processing record 47 of set 4 | eten
# Processing record 48 of set 4 | tocopilla
# Processing record 49 of set 4 | lavrentiya
# Processing record 50 of set 4 | tigzirt
# Processing record 1 of set 5 | lebu
# Processing record 2 of set 5 | saint george
# Processing record 3 of set 5 | bahia blanca
# Processing record 4 of set 5 | mecca
# Processing record 5 of set 5 | zavyalovo
# Processing record 6 of set 5 | hattiesburg
# Processing record 7 of set 5 | kondinskoye
# Processing record 8 of set 5 | karratha
# Processing record 9 of set 5 | novooleksiyivka
# Processing record 10 of set 5 | the valley
# Processing record 11 of set 5 | ribeira grande
# Processing record 12 of set 5 | anantapur
# Processing record 13 of set 5 | whyalla
# Processing record 14 of set 5 | kollumerland
# City not found. Skipping...
# Processing record 15 of set 5 | talcahuano
# Processing record 16 of set 5 | chokurdakh
# Processing record 17 of set 5 | kloulklubed
# Processing record 18 of set 5 | campana
# Processing record 19 of set 5 | asau
# Processing record 20 of set 5 | hithadhoo
# Processing record 21 of set 5 | kerteh
# City not found. Skipping...
# Processing record 22 of set 5 | tasiilaq
# Processing record 23 of set 5 | airai
# Processing record 24 of set 5 | shetpe
# Processing record 25 of set 5 | egvekinot
# Processing record 26 of set 5 | nome
# Processing record 27 of set 5 | talikota
# Processing record 28 of set 5 | oktyabrskiy
# Processing record 29 of set 5 | armacao de pera
# Processing record 30 of set 5 | kenora
# Processing record 31 of set 5 | goderich
# Processing record 32 of set 5 | saleaula
# City not found. Skipping...
# Processing record 33 of set 5 | abha
# Processing record 34 of set 5 | coquimbo
# Processing record 35 of set 5 | helena
# Processing record 36 of set 5 | boditi
# Processing record 37 of set 5 | naliya
# Processing record 38 of set 5 | pandan
# Processing record 39 of set 5 | qax
# Processing record 40 of set 5 | sapai
# City not found. Skipping...
# Processing record 41 of set 5 | suicheng
# Processing record 42 of set 5 | nantucket
# Processing record 43 of set 5 | channel-port aux basques
# Processing record 44 of set 5 | pemangkat
# Processing record 45 of set 5 | sorvag
# City not found. Skipping...
# Processing record 46 of set 5 | chuy
# Processing record 47 of set 5 | naze
# Processing record 48 of set 5 | dikson
# Processing record 49 of set 5 | pemba
# Processing record 50 of set 5 | ponnani
# Processing record 1 of set 6 | panama city
# Processing record 2 of set 6 | lodja
# Processing record 3 of set 6 | goleta
# Processing record 4 of set 6 | wilmington
# Processing record 5 of set 6 | phu ly
# Processing record 6 of set 6 | hobyo
# Processing record 7 of set 6 | half moon bay
# Processing record 8 of set 6 | namatanai
# Processing record 9 of set 6 | grindavik
# Processing record 10 of set 6 | conde
# Processing record 11 of set 6 | adrar
# Processing record 12 of set 6 | zhanaozen
# Processing record 13 of set 6 | hihifo
# City not found. Skipping...
# Processing record 14 of set 6 | sur
# Processing record 15 of set 6 | adamas
# Processing record 16 of set 6 | necochea
# Processing record 17 of set 6 | guiratinga
# Processing record 18 of set 6 | taiyuan
# Processing record 19 of set 6 | nemuro
# Processing record 20 of set 6 | provideniya
# Processing record 21 of set 6 | tagab
# Processing record 22 of set 6 | madiun
# Processing record 23 of set 6 | mao
# Processing record 24 of set 6 | griffith
# Processing record 25 of set 6 | whitehorse
# Processing record 26 of set 6 | pangkalanbuun
# Processing record 27 of set 6 | victoria
# Processing record 28 of set 6 | lokot
# Processing record 29 of set 6 | moose factory
# Processing record 30 of set 6 | mar del plata
# Processing record 31 of set 6 | khomeynishahr
# City not found. Skipping...
# Processing record 32 of set 6 | ignacio de la llave
# Processing record 33 of set 6 | warwick
# Processing record 34 of set 6 | faya
# Processing record 35 of set 6 | khandyga
# Processing record 36 of set 6 | capreol
# Processing record 37 of set 6 | avera
# Processing record 38 of set 6 | kesan
# Processing record 39 of set 6 | tripoli
# Processing record 40 of set 6 | guerrero negro
# Processing record 41 of set 6 | atikokan
# Processing record 42 of set 6 | issia
# Processing record 43 of set 6 | carnarvon
# Processing record 44 of set 6 | mogadishu
# Processing record 45 of set 6 | orotukan
# Processing record 46 of set 6 | coachella
# Processing record 47 of set 6 | talnakh
# Processing record 48 of set 6 | tabou
# Processing record 49 of set 6 | la paz
# Processing record 50 of set 6 | umm bab
# Processing record 1 of set 7 | rimouski
# Processing record 2 of set 7 | gat
# Processing record 3 of set 7 | lompoc
# Processing record 4 of set 7 | isangel
# Processing record 5 of set 7 | sinnamary
# Processing record 6 of set 7 | alice springs
# Processing record 7 of set 7 | sibi
# Processing record 8 of set 7 | bhadrachalam
# Processing record 9 of set 7 | san carlos de bariloche
# Processing record 10 of set 7 | cap malheureux
# Processing record 11 of set 7 | anadyr
# Processing record 12 of set 7 | tura
# Processing record 13 of set 7 | pangnirtung
# Processing record 14 of set 7 | bestobe
# Processing record 15 of set 7 | talakan
# Processing record 16 of set 7 | gravdal
# Processing record 17 of set 7 | klyuchi
# Processing record 18 of set 7 | sibolga
# Processing record 19 of set 7 | kahului
# Processing record 20 of set 7 | portland
# Processing record 21 of set 7 | vitim
# Processing record 22 of set 7 | jackson
# Processing record 23 of set 7 | srednekolymsk
# Processing record 24 of set 7 | altus
# Processing record 25 of set 7 | pitimbu
# Processing record 26 of set 7 | garissa
# Processing record 27 of set 7 | fortuna
# Processing record 28 of set 7 | clarence town
# Processing record 29 of set 7 | rio grande
# Processing record 30 of set 7 | tual
# Processing record 31 of set 7 | ostrovnoy
# Processing record 32 of set 7 | sasso marconi
# Processing record 33 of set 7 | makakilo city
# Processing record 34 of set 7 | manyana
# Processing record 35 of set 7 | itanhaem
# Processing record 36 of set 7 | grandview
# Processing record 37 of set 7 | hamilton
# Processing record 38 of set 7 | hasaki
# Processing record 39 of set 7 | villa maria
# Processing record 40 of set 7 | baykit
# Processing record 41 of set 7 | da nang
# Processing record 42 of set 7 | sitka
# Processing record 43 of set 7 | teneguiban
# City not found. Skipping...
# Processing record 44 of set 7 | kambove
# Processing record 45 of set 7 | ust-maya
# Processing record 46 of set 7 | kinanah
# City not found. Skipping...
# Processing record 47 of set 7 | amderma
# City not found. Skipping...
# Processing record 48 of set 7 | umzimvubu
# City not found. Skipping...
# Processing record 49 of set 7 | mount gambier
# Processing record 50 of set 7 | narsaq
# Processing record 1 of set 8 | thunder bay
# Processing record 2 of set 8 | vila velha
# Processing record 3 of set 8 | ouallam
# Processing record 4 of set 8 | ingraj bazar
# Processing record 5 of set 8 | panjab
# Processing record 6 of set 8 | wajima
# Processing record 7 of set 8 | shingu
# Processing record 8 of set 8 | rabo de peixe
# Processing record 9 of set 8 | ahipara
# Processing record 10 of set 8 | jujuy
# City not found. Skipping...
# Processing record 11 of set 8 | vadso
# Processing record 12 of set 8 | patiya
# Processing record 13 of set 8 | rockhampton
# Processing record 14 of set 8 | ndende
# Processing record 15 of set 8 | champerico
# Processing record 16 of set 8 | inirida
# Processing record 17 of set 8 | chancay
# Processing record 18 of set 8 | namibe
# Processing record 19 of set 8 | upernavik
# Processing record 20 of set 8 | basmat
# Processing record 21 of set 8 | bereda
# Processing record 22 of set 8 | north platte
# Processing record 23 of set 8 | borogontsy
# Processing record 24 of set 8 | tagusao
# Processing record 25 of set 8 | kabinda
# Processing record 26 of set 8 | quatre cocos
# Processing record 27 of set 8 | bellevue
# Processing record 28 of set 8 | hauzenberg
# Processing record 29 of set 8 | umm kaddadah
# Processing record 30 of set 8 | torbay
# Processing record 31 of set 8 | kangaatsiaq
# Processing record 32 of set 8 | vaitupu
# City not found. Skipping...
# Processing record 33 of set 8 | sawakin
# Processing record 34 of set 8 | takoradi
# Processing record 35 of set 8 | mouila
# Processing record 36 of set 8 | ahuimanu
# Processing record 37 of set 8 | qrendi
# Processing record 38 of set 8 | mrirt
# City not found. Skipping...
# Processing record 39 of set 8 | sao raimundo das mangabeiras
# Processing record 40 of set 8 | zhigansk
# Processing record 41 of set 8 | lata
# Processing record 42 of set 8 | maceio
# Processing record 43 of set 8 | cessnock
# Processing record 44 of set 8 | grand river south east
# City not found. Skipping...
# Processing record 45 of set 8 | yar-sale
# Processing record 46 of set 8 | palu
# Processing record 47 of set 8 | kavaratti
# Processing record 48 of set 8 | tabiauea
# City not found. Skipping...
# Processing record 49 of set 8 | denpasar
# Processing record 50 of set 8 | botwood
# Processing record 1 of set 9 | nhamunda
# Processing record 2 of set 9 | port blair
# Processing record 3 of set 9 | qui nhon
# Processing record 4 of set 9 | funtua
# Processing record 5 of set 9 | shchelyayur
# City not found. Skipping...
# Processing record 6 of set 9 | rancho veloz
# Processing record 7 of set 9 | along
# Processing record 8 of set 9 | severobaykalsk
# Processing record 9 of set 9 | berlevag
# Processing record 10 of set 9 | muli
# Processing record 11 of set 9 | hovd
# Processing record 12 of set 9 | spirit river
# Processing record 13 of set 9 | luanda
# Processing record 14 of set 9 | nova olinda do norte
# Processing record 15 of set 9 | astoria
# Processing record 16 of set 9 | rize
# Processing record 17 of set 9 | kroya
# Processing record 18 of set 9 | maragogi
# Processing record 19 of set 9 | broken hill
# Processing record 20 of set 9 | sorland
# Processing record 21 of set 9 | sistranda
# Processing record 22 of set 9 | touros
# Processing record 23 of set 9 | kankaanpaa
# Processing record 24 of set 9 | teya
# Processing record 25 of set 9 | praya
# Processing record 26 of set 9 | westport
# Processing record 27 of set 9 | kaniama
# Processing record 28 of set 9 | bilma
# Processing record 29 of set 9 | hounde
# Processing record 30 of set 9 | pirovskoye
# Processing record 31 of set 9 | mandalgovi
# Processing record 32 of set 9 | dongsheng
# Processing record 33 of set 9 | de-kastri
# Processing record 34 of set 9 | mongo
# Processing record 35 of set 9 | ascension
# Processing record 36 of set 9 | prince rupert
# Processing record 37 of set 9 | sao jose da coroa grande
# Processing record 38 of set 9 | manzanillo
# Processing record 39 of set 9 | mahebourg
# Processing record 40 of set 9 | fukue
# Processing record 41 of set 9 | nabire
# Processing record 42 of set 9 | gazanjyk
# Processing record 43 of set 9 | isla mujeres
# Processing record 44 of set 9 | thomaston
# Processing record 45 of set 9 | dao
# Processing record 46 of set 9 | bazarnyye mataki
# Processing record 47 of set 9 | mackay
# Processing record 48 of set 9 | hami
# Processing record 49 of set 9 | glenwood springs
# Processing record 50 of set 9 | wladyslawowo
# Processing record 1 of set 10 | bathsheba
# Processing record 2 of set 10 | deputatskiy
# Processing record 3 of set 10 | richards bay
# Processing record 4 of set 10 | vanimo
# Processing record 5 of set 10 | fairbanks
# Processing record 6 of set 10 | zhezkazgan
# Processing record 7 of set 10 | bismarck
# Processing record 8 of set 10 | dharchula
# Processing record 9 of set 10 | toyooka
# Processing record 10 of set 10 | beaverlodge
# Processing record 11 of set 10 | kotelnikovo
# Processing record 12 of set 10 | iguape
# Processing record 13 of set 10 | emba
# Processing record 14 of set 10 | humaita
# Processing record 15 of set 10 | sorong
# Processing record 16 of set 10 | olafsvik
# Processing record 17 of set 10 | lazaro cardenas
# Processing record 18 of set 10 | soissons
# Processing record 19 of set 10 | itarema
# Processing record 20 of set 10 | pulaski
# Processing record 21 of set 10 | sooke
# Processing record 22 of set 10 | beringovskiy
# Processing record 23 of set 10 | yenagoa
# Processing record 24 of set 10 | pompeu
# Processing record 25 of set 10 | samusu
# City not found. Skipping...
# Processing record 26 of set 10 | pisco
# Processing record 27 of set 10 | nouadhibou
# Processing record 28 of set 10 | dzhebariki-khaya
# Processing record 29 of set 10 | ayacucho
# Processing record 30 of set 10 | itacare
# Processing record 31 of set 10 | hay river
# Processing record 32 of set 10 | yuancheng
# Processing record 33 of set 10 | cabra
# Processing record 34 of set 10 | hudson bay
# Processing record 35 of set 10 | gonbad-e qabus
# Processing record 36 of set 10 | oistins
# Processing record 37 of set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing record 38 of set 10 | torit
# Processing record 39 of set 10 | xuddur
# Processing record 40 of set 10 | fare
# Processing record 41 of set 10 | payo
# Processing record 42 of set 10 | waingapu
# Processing record 43 of set 10 | san cristobal
# Processing record 44 of set 10 | bundaberg
# Processing record 45 of set 10 | birao
# Processing record 46 of set 10 | skjervoy
# Processing record 47 of set 10 | oranjestad
# Processing record 48 of set 10 | mergui
# City not found. Skipping...
# Processing record 49 of set 10 | bandarbeyla
# Processing record 50 of set 10 | mirabad
# Processing record 1 of set 11 | barahona
# Processing record 2 of set 11 | arlit
# Processing record 3 of set 11 | nioro
# Processing record 4 of set 11 | khakhea
# Processing record 5 of set 11 | saldanha
# Processing record 6 of set 11 | kondoa
# Processing record 7 of set 11 | piranshahr
# Processing record 8 of set 11 | launceston
# Processing record 9 of set 11 | haines junction
# Processing record 10 of set 11 | inderborskiy
# City not found. Skipping...
# Processing record 11 of set 11 | baraki barak
# Processing record 12 of set 11 | labuhan
# Processing record 13 of set 11 | hofn
# Processing record 14 of set 11 | praia
# Processing record 15 of set 11 | ishigaki
# Processing record 16 of set 11 | ulladulla
# Processing record 17 of set 11 | matagami
# Processing record 18 of set 11 | navahrudak
# Processing record 19 of set 11 | korla
# Processing record 20 of set 11 | hambantota
# Processing record 21 of set 11 | tombouctou
# Processing record 22 of set 11 | khonuu
# City not found. Skipping...
# Processing record 23 of set 11 | nicoya
# Processing record 24 of set 11 | linxia
# Processing record 25 of set 11 | randolph
# Processing record 26 of set 11 | lang suan
# Processing record 27 of set 11 | dolinsk
# Processing record 28 of set 11 | bongandanga
# Processing record 29 of set 11 | ahmadabad
# Processing record 30 of set 11 | wiang sa
# Processing record 31 of set 11 | barmer
# Processing record 32 of set 11 | beloha
# Processing record 33 of set 11 | tulun
# Processing record 34 of set 11 | dingle
# Processing record 35 of set 11 | shimoda
# Processing record 36 of set 11 | nuuk
# Processing record 37 of set 11 | vondrozo
# Processing record 38 of set 11 | mount hagen
# Processing record 39 of set 11 | mananjary
# Processing record 40 of set 11 | pachino
# Processing record 41 of set 11 | khuzhir
# Processing record 42 of set 11 | lencois paulista
# Processing record 43 of set 11 | czersk
# Processing record 44 of set 11 | college
# Processing record 45 of set 11 | montrose
# Processing record 46 of set 11 | mangalam
# Processing record 47 of set 11 | sapernoye
# Processing record 48 of set 11 | kisangani
# Processing record 49 of set 11 | ulaanbaatar
# Processing record 50 of set 11 | ati
# Processing record 1 of set 12 | neiafu
# Processing record 2 of set 12 | ruwi
# Processing record 3 of set 12 | grand-santi
# Processing record 4 of set 12 | geraldton
# Processing record 5 of set 12 | tomatlan
# Processing record 6 of set 12 | coihaique
# Processing record 7 of set 12 | paragominas
# Processing record 8 of set 12 | la ronge
# Processing record 9 of set 12 | mount pleasant
# Processing record 10 of set 12 | doume
# Processing record 11 of set 12 | dubuque
# Processing record 12 of set 12 | gold coast
# Processing record 13 of set 12 | sao joao da barra
# Processing record 14 of set 12 | cabo san lucas
# Processing record 15 of set 12 | chabahar
# Processing record 16 of set 12 | komsomolskiy
# Processing record 17 of set 12 | oranjemund
# Processing record 18 of set 12 | cockburn town
# Processing record 19 of set 12 | worthington
# Processing record 20 of set 12 | marsa matruh
# Processing record 21 of set 12 | presidencia roque saenz pena
# Processing record 22 of set 12 | dunedin
# Processing record 23 of set 12 | nyurba
# Processing record 24 of set 12 | dongkan
# Processing record 25 of set 12 | iracoubo
# Processing record 26 of set 12 | akyab
# Processing record 27 of set 12 | agadir
# Processing record 28 of set 12 | mantua
# Processing record 29 of set 12 | tome-acu
# City not found. Skipping...
# Processing record 30 of set 12 | kushiro
# Processing record 31 of set 12 | sulangan
# Processing record 32 of set 12 | minab
# Processing record 33 of set 12 | kidal
# Processing record 34 of set 12 | saint-gabriel
# Processing record 35 of set 12 | naryan-mar
# Processing record 36 of set 12 | danilovka
# Processing record 37 of set 12 | kapit
# Processing record 38 of set 12 | vao
# Processing record 39 of set 12 | ordzhonikidze
# Processing record 40 of set 12 | viedma
# Processing record 41 of set 12 | port moresby
# Processing record 42 of set 12 | havre-saint-pierre
# Processing record 43 of set 12 | samarai
# Processing record 44 of set 12 | te anau
# Processing record 45 of set 12 | san patricio
# Processing record 46 of set 12 | puerto colombia
# Processing record 47 of set 12 | tortoli
# Processing record 48 of set 12 | grants
# Processing record 49 of set 12 | tucuma
# Processing record 50 of set 12 | tera
# Processing record 1 of set 13 | gimli
# Processing record 2 of set 13 | tahta
# Processing record 3 of set 13 | oda
# Processing record 4 of set 13 | najran
# Processing record 5 of set 13 | babushkin
# Processing record 6 of set 13 | jibuti
# Processing record 7 of set 13 | collie
# Processing record 8 of set 13 | alekseyevka
# Processing record 9 of set 13 | camana
# Processing record 10 of set 13 | waipawa
# Processing record 11 of set 13 | sombrerete
# Processing record 12 of set 13 | araouane
# Processing record 13 of set 13 | kayerkan
# Processing record 14 of set 13 | christchurch
# Processing record 15 of set 13 | atambua
# Processing record 16 of set 13 | townsville
# Processing record 17 of set 13 | tuggurt
# City not found. Skipping...
# Processing record 18 of set 13 | culleredo
# Processing record 19 of set 13 | fremont
# Processing record 20 of set 13 | surt
# Processing record 21 of set 13 | san roque
# Processing record 22 of set 13 | alofi
# Processing record 23 of set 13 | antofagasta
# Processing record 24 of set 13 | kaeo
# Processing record 25 of set 13 | aransas pass
# Processing record 26 of set 13 | dubbo
# Processing record 27 of set 13 | gilgit
# Processing record 28 of set 13 | shangrao
# Processing record 29 of set 13 | taksimo
# Processing record 30 of set 13 | tapaua
# City not found. Skipping...
# Processing record 31 of set 13 | kachikau
# City not found. Skipping...
# Processing record 32 of set 13 | pietarsaari
# Processing record 33 of set 13 | bubaque
# Processing record 34 of set 13 | sumbe
# Processing record 35 of set 13 | iqaluit
# Processing record 36 of set 13 | ijaki
# City not found. Skipping...
# Processing record 37 of set 13 | paamiut
# Processing record 38 of set 13 | sheffield
# Processing record 39 of set 13 | george
# Processing record 40 of set 13 | krasnyy chikoy
# Processing record 41 of set 13 | dalvik
# Processing record 42 of set 13 | ostersund
# Processing record 43 of set 13 | ketchikan
# Processing record 44 of set 13 | ekhabi
# Processing record 45 of set 13 | aqtobe
# Processing record 46 of set 13 | senanga
# Processing record 47 of set 13 | frunze
# Processing record 48 of set 13 | alvaraes
# Processing record 49 of set 13 | aksu
# Processing record 50 of set 13 | mount isa
# Processing record 1 of set 14 | qafsah
# City not found. Skipping...
# Processing record 2 of set 14 | shaunavon
# Processing record 3 of set 14 | vapnyarka
# Processing record 4 of set 14 | margate
# Processing record 5 of set 14 | buenos aires
# Processing record 6 of set 14 | meyungs
# City not found. Skipping...
# Processing record 7 of set 14 | barcelos
# Processing record 8 of set 14 | tubruq
# City not found. Skipping...
# Processing record 9 of set 14 | emirdag
# Processing record 10 of set 14 | kontagora
# Processing record 11 of set 14 | pital
# Processing record 12 of set 14 | jumla
# Processing record 13 of set 14 | arman
# Processing record 14 of set 14 | shenjiamen
# Processing record 15 of set 14 | honningsvag
# Processing record 16 of set 14 | vestmanna
# Processing record 17 of set 14 | acajutla
# Processing record 18 of set 14 | morros
# Processing record 19 of set 14 | boende
# Processing record 20 of set 14 | kargasok
# Processing record 21 of set 14 | matara
# Processing record 22 of set 14 | wundanyi
# Processing record 23 of set 14 | katherine
# Processing record 24 of set 14 | morondava
# Processing record 25 of set 14 | batesville
# Processing record 26 of set 14 | bonavista
# Processing record 27 of set 14 | quimper
# Processing record 28 of set 14 | cururupu
# Processing record 29 of set 14 | rab
# City not found. Skipping...
# Processing record 30 of set 14 | aswan
# Processing record 31 of set 14 | euclides da cunha
# Processing record 32 of set 14 | baldone
# Processing record 33 of set 14 | brokopondo
# Processing record 34 of set 14 | jardim
# Processing record 35 of set 14 | wagar
# Processing record 36 of set 14 | neubrandenburg
# Processing record 37 of set 14 | carthage
# Processing record 38 of set 14 | chapais
# Processing record 39 of set 14 | sayabec
# City not found. Skipping...
# Processing record 40 of set 14 | pokhara
# Processing record 41 of set 14 | grand gaube
# Processing record 42 of set 14 | buraydah
# Processing record 43 of set 14 | pacific grove
# Processing record 44 of set 14 | caravelas
# Processing record 45 of set 14 | gizo
# Processing record 46 of set 14 | siyabuswa
# Processing record 47 of set 14 | wanaka
# Processing record 48 of set 14 | freeport
# Processing record 49 of set 14 | strezhevoy
# Processing record 50 of set 14 | tuzamapan
# Processing record 1 of set 15 | kiruna
# Processing record 2 of set 15 | maku
# Processing record 3 of set 15 | kaura namoda
# Processing record 4 of set 15 | sakakah
# Processing record 5 of set 15 | khorixas
# Processing record 6 of set 15 | saint-francois
# Processing record 7 of set 15 | selenginsk
# Processing record 8 of set 15 | sangar
# Processing record 9 of set 15 | basoko
# Processing record 10 of set 15 | lakes entrance
# Processing record 11 of set 15 | chimbote
# Processing record 12 of set 15 | sabya
# Processing record 13 of set 15 | sydney
# Processing record 14 of set 15 | amahai
# Processing record 15 of set 15 | illintsi
# Processing record 16 of set 15 | auki
# Processing record 17 of set 15 | bethanien
# Processing record 18 of set 15 | kudahuvadhoo
# Processing record 19 of set 15 | pochutla
# Processing record 20 of set 15 | iskateley
# Processing record 21 of set 15 | goure
# Processing record 22 of set 15 | winslow
# Processing record 23 of set 15 | vihari
# Processing record 24 of set 15 | belaya gora
# Processing record 25 of set 15 | buka
# Processing record 26 of set 15 | juan lacaze
# Processing record 27 of set 15 | blagoyevo
# Processing record 28 of set 15 | trelew
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#establishing final length to get a sense of how many cities were skipped
len(city_data)
# Out:
# 1366

# %%
#Converting l-d to pandas df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    tuatapere -46.1333  167.6833     54.12        60          39        8.97
# 1    Tuatapere -46.1333  167.6833     54.12        60          39        8.97
# 2   butaritari   3.0707  172.7902     82.71        71          84       15.77
# 3   Butaritari   3.0707  172.7902     82.71        71          84       15.77
# 4       ugento  39.9263   18.1574     56.70        65         100       26.66
# 5       Ugento  39.9263   18.1574     56.70        65         100       26.66
# 6   bredasdorp -34.5322   20.0403     50.29        90         100        4.41
# 7   Bredasdorp -34.5322   20.0403     50.29        90         100        4.41
# 8  podporozhye  60.9112   34.1706     34.63        94           9        2.80
# 9  Podporozhye  60.9112   34.1706     34.63        94           9        2.80
#
#   Country Current Description
# 0      NZ    scattered clouds
# 1      NZ    scattered clouds
# 2      KI       broken clouds
# 3      KI       broken clouds
# 4      IT     overcast clouds
# 5      IT     overcast clouds
# 6      ZA     overcast clouds
# 7      ZA     overcast clouds
# 8      RU           clear sky
# 9      RU           clear sky

# %%
#Reordering columns
new_col_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_col_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    tuatapere      NZ -46.1333  167.6833     54.12        60          39
# 1    Tuatapere      NZ -46.1333  167.6833     54.12        60          39
# 2   butaritari      KI   3.0707  172.7902     82.71        71          84
# 3   Butaritari      KI   3.0707  172.7902     82.71        71          84
# 4       ugento      IT  39.9263   18.1574     56.70        65         100
# 5       Ugento      IT  39.9263   18.1574     56.70        65         100
# 6   bredasdorp      ZA -34.5322   20.0403     50.29        90         100
# 7   Bredasdorp      ZA -34.5322   20.0403     50.29        90         100
# 8  podporozhye      RU  60.9112   34.1706     34.63        94           9
# 9  Podporozhye      RU  60.9112   34.1706     34.63        94           9
#
#    Wind Speed Current Description
# 0        8.97    scattered clouds
# 1        8.97    scattered clouds
# 2       15.77       broken clouds
# 3       15.77       broken clouds
# 4       26.66     overcast clouds
# 5       26.66     overcast clouds
# 6        4.41     overcast clouds
# 7        4.41     overcast clouds
# 8        2.80           clear sky
# 9        2.80           clear sky

# %%
#Working to clean data and remove duplicates
city_data_df["is_duplicate"]= city_data_df["Lat"].duplicated()

city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    tuatapere      NZ -46.1333  167.6833     54.12        60          39
# 1    Tuatapere      NZ -46.1333  167.6833     54.12        60          39
# 2   butaritari      KI   3.0707  172.7902     82.71        71          84
# 3   Butaritari      KI   3.0707  172.7902     82.71        71          84
# 4       ugento      IT  39.9263   18.1574     56.70        65         100
# 5       Ugento      IT  39.9263   18.1574     56.70        65         100
# 6   bredasdorp      ZA -34.5322   20.0403     50.29        90         100
# 7   Bredasdorp      ZA -34.5322   20.0403     50.29        90         100
# 8  podporozhye      RU  60.9112   34.1706     34.63        94           9
# 9  Podporozhye      RU  60.9112   34.1706     34.63        94           9
#
#    Wind Speed Current Description  is_duplicate
# 0        8.97    scattered clouds         False
# 1        8.97    scattered clouds          True
# 2       15.77       broken clouds         False
# 3       15.77       broken clouds          True
# 4       26.66     overcast clouds         False
# 5       26.66     overcast clouds          True
# 6        4.41     overcast clouds         False
# 7        4.41     overcast clouds          True
# 8        2.80           clear sky         False
# 9        2.80           clear sky          True

# %%
# Droping duplicates using the boolean above as a guide
city_data_df.drop(city_data_df[city_data_df['is_duplicate'] == False].index, inplace=True)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1    Tuatapere      NZ -46.1333  167.6833     54.12        60          39
# 3   Butaritari      KI   3.0707  172.7902     82.71        71          84
# 5       Ugento      IT  39.9263   18.1574     56.70        65         100
# 7   Bredasdorp      ZA -34.5322   20.0403     50.29        90         100
# 9  Podporozhye      RU  60.9112   34.1706     34.63        94           9
#
#    Wind Speed Current Description  is_duplicate
# 1        8.97    scattered clouds          True
# 3       15.77       broken clouds          True
# 5       26.66     overcast clouds          True
# 7        4.41     overcast clouds          True
# 9        2.80           clear sky          True

# %%
city_data_df = city_data_df.drop('is_duplicate', 1)
city_data_df.head()
# Out:
# <ipython-input-41-41d56b233971>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   city_data_df = city_data_df.drop('is_duplicate', 1)
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1    Tuatapere      NZ -46.1333  167.6833     54.12        60          39
# 3   Butaritari      KI   3.0707  172.7902     82.71        71          84
# 5       Ugento      IT  39.9263   18.1574     56.70        65         100
# 7   Bredasdorp      ZA -34.5322   20.0403     50.29        90         100
# 9  Podporozhye      RU  60.9112   34.1706     34.63        94           9
#
#    Wind Speed Current Description
# 1        8.97    scattered clouds
# 3       15.77       broken clouds
# 5       26.66     overcast clouds
# 7        4.41     overcast clouds
# 9        2.80           clear sky

# %%
#Creating output file path
output_path = "Weather_Database/WeatherPy_Database.csv"

#Exporting city_data
city_data_df.to_csv(output_path, index_label = "City_ID")

# %%
file_name = "Weather_Database/WeatherPy_Database.csv"
file_name_output = "Weather_Database/WeatherPy_Database.csv"
