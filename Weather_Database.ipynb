# %% [markdown]
# # Deliverable 1 - Collecting Datapoints From an API

# %%
#Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time

from datetime import datetime

from citipy import citipy
from config import WEATHER_API_KEY

# %%
# Making url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + WEATHER_API_KEY

# %%
#Creating set of random coordinates
num_locs=2000

lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Adding the coordinates to a list
coordinates = list(lat_lngs)

# %%
# Create lists to store cities and countries.
cities = []

# Loop over the coordinates.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Only append if it is a new city.
    if city not in cities:
        cities.append(city)
    
# Sanity checks:
print (f"Initial count of cities: {len(cities)}")
# Out:
# Initial count of cities: 755

# %%
# Base URL for the OpenWeather API call.
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + WEATHER_API_KEY

print(f"Beginning Data Retrieval")
print("---------------------------\n")

# Create an empty list to hold the weather data.
city_data = []

#Start and create counter lists
record_count = 1
set_count = 1

# Initialize variables to keep track of rate limiting.
start_time = int(time.time())
current_time = start_time

# Loop over all cities.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    print (f"Processing record {record_count} of set {set_count} | {city}")
    record_count += 1
        
    if i > 0:
        # Get current time.
        current_time = int(time.time())
        
#         # If needed introduce a sleep process so not to get blocked by API, if we surpass a certain amount of calls and 1 min hasn't passed, the code will add a sleep break
#     elif current_time - start_time < 60:
#         sleep_time = 60 - (current_time - start_time)
#         print (f"Introducting a sleep of {sleep_time} seconds!")
#         time.sleep(sleep_time) 
        
            # Get the new start time.
    start_time = int(time.time())
        
    
    # Create endpoint URL with each city.
    city_url = base_url + "&q=" + city.replace(" ","+")
    
    #https://docs.python.org/3.6/tutorial/errors.html
    try:
    
        city_weather = requests.get(city_url).json()
        lat = city_weather["coord"]["lat"]
        lng = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        current = city_weather["weather"][0]["description"]

        #Convert date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
        #Append city info to city_data list.
        city_data.append({"City": city,
                          "Lat": lat,
                          "Lng": lng,
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": clouds,
                          "Wind Speed": wind,
                          "Country": country,
                          "Current Description": current})
        
        city_weather = requests.get(city_url).json()
    
        
        # Parse out the needed data.
        lat = city_weather["coord"]["lat"]
        lng = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        desc = city_weather['weather'][0]['description']

        # Append the city information into city_data list.
        city_data.append({'City': city.title(),
                          'Lat': lat,
                          'Lng': lng,
                          'Max Temp': max_temp,
                          'Humidity': humidity,
                          'Cloudiness': clouds,
                          'Wind Speed': wind,
                          'Country': country,
                          'Current Description': desc})

       
    # Skip errors
    except:
        print("City not found. Skipping...")
        pass
    
#Indicate Data Loading complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
#
# Processing record 1 of set 1 | pratapgarh
# Processing record 2 of set 1 | bengkulu
# Processing record 3 of set 1 | upernavik
# Processing record 4 of set 1 | hermanus
# Processing record 5 of set 1 | khatanga
# Processing record 6 of set 1 | hofn
# Processing record 7 of set 1 | atuona
# Processing record 8 of set 1 | oyek
# Processing record 9 of set 1 | zilupe
# Processing record 10 of set 1 | kamyshin
# Processing record 11 of set 1 | touros
# Processing record 12 of set 1 | butaritari
# Processing record 13 of set 1 | avarua
# Processing record 14 of set 1 | saint-philippe
# Processing record 15 of set 1 | tsihombe
# City not found. Skipping...
# Processing record 16 of set 1 | hithadhoo
# Processing record 17 of set 1 | chokurdakh
# Processing record 18 of set 1 | ushuaia
# Processing record 19 of set 1 | sechura
# Processing record 20 of set 1 | yellowknife
# Processing record 21 of set 1 | baikunthpur
# Processing record 22 of set 1 | busselton
# Processing record 23 of set 1 | mar del plata
# Processing record 24 of set 1 | hobyo
# Processing record 25 of set 1 | cabedelo
# Processing record 26 of set 1 | port hedland
# Processing record 27 of set 1 | moroto
# Processing record 28 of set 1 | hoyanger
# Processing record 29 of set 1 | cape town
# Processing record 30 of set 1 | los llanos de aridane
# Processing record 31 of set 1 | saint-pierre
# Processing record 32 of set 1 | punta arenas
# Processing record 33 of set 1 | san patricio
# Processing record 34 of set 1 | mullaitivu
# City not found. Skipping...
# Processing record 35 of set 1 | shelburne
# Processing record 36 of set 1 | airai
# Processing record 37 of set 1 | tura
# Processing record 38 of set 1 | castro
# Processing record 39 of set 1 | bima
# Processing record 40 of set 1 | bredasdorp
# Processing record 41 of set 1 | bethel
# Processing record 42 of set 1 | mayo
# Processing record 43 of set 1 | stulovo
# Processing record 44 of set 1 | bouna
# Processing record 45 of set 1 | biltine
# Processing record 46 of set 1 | bluff
# Processing record 47 of set 1 | kruisfontein
# Processing record 48 of set 1 | namatanai
# Processing record 49 of set 1 | tuktoyaktuk
# Processing record 50 of set 1 | victoria
# Processing record 1 of set 2 | ibra
# Processing record 2 of set 2 | surt
# Processing record 3 of set 2 | new norfolk
# Processing record 4 of set 2 | iqaluit
# Processing record 5 of set 2 | hamilton
# Processing record 6 of set 2 | rikitea
# Processing record 7 of set 2 | sao filipe
# Processing record 8 of set 2 | kavaratti
# Processing record 9 of set 2 | kodiak
# Processing record 10 of set 2 | taolanaro
# City not found. Skipping...
# Processing record 11 of set 2 | dali
# Processing record 12 of set 2 | dubti
# Processing record 13 of set 2 | manoel urbano
# Processing record 14 of set 2 | cherskiy
# Processing record 15 of set 2 | port alfred
# Processing record 16 of set 2 | torbay
# Processing record 17 of set 2 | mataura
# Processing record 18 of set 2 | port lincoln
# Processing record 19 of set 2 | ahvaz
# Processing record 20 of set 2 | cidreira
# Processing record 21 of set 2 | kapaa
# Processing record 22 of set 2 | oksfjord
# Processing record 23 of set 2 | abu dhabi
# Processing record 24 of set 2 | lompoc
# Processing record 25 of set 2 | lebu
# Processing record 26 of set 2 | buala
# Processing record 27 of set 2 | theunissen
# Processing record 28 of set 2 | teahupoo
# Processing record 29 of set 2 | karkaralinsk
# City not found. Skipping...
# Processing record 30 of set 2 | half moon bay
# Processing record 31 of set 2 | guarapari
# Processing record 32 of set 2 | norman wells
# Processing record 33 of set 2 | vaini
# Processing record 34 of set 2 | natal
# Processing record 35 of set 2 | pangnirtung
# Processing record 36 of set 2 | rungata
# City not found. Skipping...
# Processing record 37 of set 2 | chara
# Processing record 38 of set 2 | korla
# Processing record 39 of set 2 | preobrazheniye
# Processing record 40 of set 2 | aykhal
# Processing record 41 of set 2 | qaanaaq
# Processing record 42 of set 2 | puerto ayora
# Processing record 43 of set 2 | jawhar
# Processing record 44 of set 2 | eyl
# Processing record 45 of set 2 | fortuna
# Processing record 46 of set 2 | hobart
# Processing record 47 of set 2 | ayolas
# Processing record 48 of set 2 | albany
# Processing record 49 of set 2 | pangai
# Processing record 50 of set 2 | clyde river
# Processing record 1 of set 3 | beloha
# Processing record 2 of set 3 | nizhneyansk
# City not found. Skipping...
# Processing record 3 of set 3 | hilo
# Processing record 4 of set 3 | barentsburg
# City not found. Skipping...
# Processing record 5 of set 3 | saskylakh
# Processing record 6 of set 3 | esperance
# Processing record 7 of set 3 | hazorasp
# Processing record 8 of set 3 | armacao dos buzios
# City not found. Skipping...
# Processing record 9 of set 3 | olafsvik
# Processing record 10 of set 3 | college
# Processing record 11 of set 3 | severnoye
# Processing record 12 of set 3 | adrar
# Processing record 13 of set 3 | brae
# Processing record 14 of set 3 | port elizabeth
# Processing record 15 of set 3 | abnub
# Processing record 16 of set 3 | ribeira grande
# Processing record 17 of set 3 | ambunti
# Processing record 18 of set 3 | tomatlan
# Processing record 19 of set 3 | estevan
# Processing record 20 of set 3 | butembo
# Processing record 21 of set 3 | santa cecilia
# Processing record 22 of set 3 | lagoa
# Processing record 23 of set 3 | barrow
# Processing record 24 of set 3 | umm kaddadah
# Processing record 25 of set 3 | bad mergentheim
# Processing record 26 of set 3 | monrovia
# Processing record 27 of set 3 | jamestown
# Processing record 28 of set 3 | verkhnevilyuysk
# Processing record 29 of set 3 | arlit
# Processing record 30 of set 3 | thompson
# Processing record 31 of set 3 | grand river south east
# City not found. Skipping...
# Processing record 32 of set 3 | vanimo
# Processing record 33 of set 3 | palembang
# Processing record 34 of set 3 | hirara
# Processing record 35 of set 3 | arraial do cabo
# Processing record 36 of set 3 | xining
# Processing record 37 of set 3 | tiksi
# Processing record 38 of set 3 | leningradskiy
# Processing record 39 of set 3 | lavrentiya
# Processing record 40 of set 3 | lensk
# Processing record 41 of set 3 | itarema
# Processing record 42 of set 3 | guerrero negro
# Processing record 43 of set 3 | sibolga
# Processing record 44 of set 3 | tawang
# Processing record 45 of set 3 | umzimvubu
# City not found. Skipping...
# Processing record 46 of set 3 | palmer
# Processing record 47 of set 3 | gmunden
# Processing record 48 of set 3 | matara
# Processing record 49 of set 3 | bambous virieux
# Processing record 50 of set 3 | inuvik
# Processing record 1 of set 4 | tadine
# Processing record 2 of set 4 | vila do maio
# Processing record 3 of set 4 | coffs harbour
# Processing record 4 of set 4 | narsaq
# Processing record 5 of set 4 | srednekolymsk
# Processing record 6 of set 4 | hualmay
# Processing record 7 of set 4 | naryan-mar
# Processing record 8 of set 4 | krasnoselkup
# Processing record 9 of set 4 | shache
# Processing record 10 of set 4 | sarkand
# Processing record 11 of set 4 | sept-iles
# Processing record 12 of set 4 | huarmey
# Processing record 13 of set 4 | alice springs
# Processing record 14 of set 4 | ostrovnoy
# Processing record 15 of set 4 | suleja
# Processing record 16 of set 4 | takoradi
# Processing record 17 of set 4 | miranda de ebro
# Processing record 18 of set 4 | tuatapere
# Processing record 19 of set 4 | grootfontein
# Processing record 20 of set 4 | sentyabrskiy
# City not found. Skipping...
# Processing record 21 of set 4 | zhigansk
# Processing record 22 of set 4 | gat
# Processing record 23 of set 4 | pevek
# Processing record 24 of set 4 | abu samrah
# Processing record 25 of set 4 | mantua
# Processing record 26 of set 4 | masterton
# Processing record 27 of set 4 | roslavl
# Processing record 28 of set 4 | na wa
# Processing record 29 of set 4 | ponta do sol
# Processing record 30 of set 4 | bodden town
# Processing record 31 of set 4 | walvis bay
# Processing record 32 of set 4 | kaitangata
# Processing record 33 of set 4 | belaya gora
# Processing record 34 of set 4 | codrington
# Processing record 35 of set 4 | carnarvon
# Processing record 36 of set 4 | bagalkot
# Processing record 37 of set 4 | lorengau
# Processing record 38 of set 4 | dharchula
# Processing record 39 of set 4 | nioro
# Processing record 40 of set 4 | qala
# Processing record 41 of set 4 | gunjur
# Processing record 42 of set 4 | alofi
# Processing record 43 of set 4 | lixourion
# Processing record 44 of set 4 | east london
# Processing record 45 of set 4 | new ulm
# Processing record 46 of set 4 | taguatinga
# Processing record 47 of set 4 | dire dawa
# Processing record 48 of set 4 | cockburn town
# Processing record 49 of set 4 | hervey bay
# Processing record 50 of set 4 | roma
# Processing record 1 of set 5 | amantea
# Processing record 2 of set 5 | chuy
# Processing record 3 of set 5 | ilulissat
# Processing record 4 of set 5 | alugan
# Processing record 5 of set 5 | sayyan
# Processing record 6 of set 5 | camargo
# Processing record 7 of set 5 | keelung
# Processing record 8 of set 5 | georgetown
# Processing record 9 of set 5 | severo-kurilsk
# Processing record 10 of set 5 | sargur
# Processing record 11 of set 5 | columbus
# Processing record 12 of set 5 | samarai
# Processing record 13 of set 5 | namibe
# Processing record 14 of set 5 | mackenzie
# Processing record 15 of set 5 | auki
# Processing record 16 of set 5 | khudumelapye
# Processing record 17 of set 5 | port blair
# Processing record 18 of set 5 | pisco
# Processing record 19 of set 5 | graaff-reinet
# Processing record 20 of set 5 | dikson
# Processing record 21 of set 5 | panzhihua
# Processing record 22 of set 5 | taoudenni
# Processing record 23 of set 5 | deputatskiy
# Processing record 24 of set 5 | vondrozo
# Processing record 25 of set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing record 26 of set 5 | luderitz
# Processing record 27 of set 5 | nanortalik
# Processing record 28 of set 5 | cabo san lucas
# Processing record 29 of set 5 | kavieng
# Processing record 30 of set 5 | santarem
# Processing record 31 of set 5 | bonthe
# Processing record 32 of set 5 | toucheng
# Processing record 33 of set 5 | macklin
# Processing record 34 of set 5 | babushkin
# Processing record 35 of set 5 | altay
# Processing record 36 of set 5 | poronaysk
# Processing record 37 of set 5 | portland
# Processing record 38 of set 5 | gayeri
# Processing record 39 of set 5 | casablanca
# Processing record 40 of set 5 | wahpeton
# Processing record 41 of set 5 | yunjinghong
# City not found. Skipping...
# Processing record 42 of set 5 | ambalavao
# Processing record 43 of set 5 | sistranda
# Processing record 44 of set 5 | saleaula
# City not found. Skipping...
# Processing record 45 of set 5 | goderich

# %%
#establishing final length to get a sense of how many cities were skipped
len(city_data)

# %%
#Converting l-d to pandas df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
#Reordering columns
new_col_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_col_order]
city_data_df.head(10)

# %%
#Creating output file path
output_path = "Weather_Database/WeatherPy_Database.csv"

#Exporting city_data
city_data_df.to_csv(output_path, index_label = "City_ID")
